# %% [markdown]
# <a href="https://colab.research.google.com/github/RussianRightWing/VrLabs/blob/main/VRLabs.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Лаба 1

# %%
import cv2
from matplotlib import pyplot as plt

img = cv2.imread("/content/drive/MyDrive/VrLabs/lab1bexa.bmp")

plt.imshow(img)
plt.show()

# %%
img2 = cv2.cvtColor(img, cv2.COLOR_BGR2HSV)

plt.imshow(img2)
plt.show()

# %%
t = img2[:,:,0]

plt.imshow(t)
plt.show()

# %%
t = img2[:,:,1]

plt.imshow(t)
plt.show()

# %%
t = img2[:,:,2]

plt.imshow(t)
plt.show()

# %% [markdown]
# # Лаба 2
